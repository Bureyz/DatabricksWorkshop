# %% [markdown]
# # [Tytuł Notebooka] - [Demo/Workshop]
#
# **Cel szkoleniowy:** [Konkretny, mierzalny cel zgodny z agendą KION_DETAIL]
#
# **Zakres tematyczny:**
# - [Temat 1 z agendy]
# - [Temat 2 z agendy]
# - [Temat 3 z agendy]

# %% [markdown]
# ## Kontekst i wymagania
#
# - **Dzień szkolenia**: Dzień [1/2/3] - [Nazwa modułu]
# - **Typ notebooka**: [Demo/Workshop]
# - **Wymagania techniczne**:
#   - Databricks Runtime 13.0+ (zalecane: 14.3 LTS)
#   - Unity Catalog włączony
#   - Uprawnienia: CREATE TABLE, CREATE SCHEMA, SELECT, MODIFY
#   - Klaster: [Standard/High Concurrency] z [X] workers

# %%
## Wstęp teoretyczny

**Cel sekcji:** [Opis celu sekcji]

**Podstawowe pojęcia:**
- **[Pojęcie 1]**: [Definicja lub wyjaśnienie]
- **[Pojęcie 2]**: [Definicja lub wyjaśnienie]

**Dlaczego to ważne?**
[Krótki opis znaczenia omawianego tematu w kontekście szkolenia lub projektu.]

# %% [markdown]
# ## Izolacja per użytkownik
#
# Uruchom skrypt inicjalizacyjny dla per-user izolacji katalogów i schematów:

# %%
# %run ./00_setup

# %% [markdown]
# ## Konfiguracja
#
# Import bibliotek i ustawienie zmiennych środowiskowych:

# %%
from pyspark.sql import functions as F
from pyspark.sql.types import *
from pyspark.sql.window import Window
import re
from datetime import datetime, timedelta

# Wyświetl kontekst użytkownika (zmienne z 00_user_context_init)
print("=== Kontekst użytkownika ===")
print(f"Katalog: {CATALOG}")
print(f"Schema Bronze: {BRONZE_SCHEMA}")
print(f"Schema Silver: {SILVER_SCHEMA}")
print(f"Schema Gold: {GOLD_SCHEMA}")
print(f"Użytkownik: {raw_user}")

# Ustaw katalog i schemat jako domyślne
spark.sql(f"USE CATALOG {CATALOG}")
spark.sql(f"USE SCHEMA {BRONZE_SCHEMA}")

# %% [markdown]
# ## Sekcja 1: [Nazwa pierwszej sekcji tematycznej]
#
# **Wprowadzenie teoretyczne:**
#
# [Zwięzłe wyjaśnienie konceptu - 3-5 zdań bez emotikon]
#
# **Kluczowe pojęcia:**
# - **[Pojęcie 1]**: [Definicja]
# - **[Pojęcie 2]**: [Definicja]
# - **[Pojęcie 3]**: [Definicja]
#
# **Zastosowanie praktyczne:**
# - [Przypadek użycia 1]
# - [Przypadek użycia 2]

# %% [markdown]
# ### Przykład 1.1: [Nazwa przykładu]
#
# **Cel:** [Co demonstruje ten przykład]
#
# **Podejście:**
# 1. [Krok 1]
# 2. [Krok 2]
# 3. [Krok 3]

# %%
# Przykład 1.1 - [Krótki opis]

# TODO (dla warsztatów): Uzupełnij kod zgodnie z instrukcjami
# Dla demo: kompletny, działający kod

# Twój kod tutaj

# %% [markdown]
# **Wyjaśnienie:**
#
# [Wyjaśnienie co robi kod, dlaczego, jakie są kluczowe aspekty]

# %% [markdown]
# ### Przykład 1.2: [Nazwa przykładu]
#
# **Cel:** [Co demonstruje ten przykład]

# %%
# Przykład 1.2 - [Krótki opis]

# Twój kod tutaj

# %% [markdown]
# ## Sekcja 2: [Nazwa drugiej sekcji tematycznej]
#
# **Wprowadzenie teoretyczne:**
#
# [Wyjaśnienie konceptu]

# %% [markdown]
# ### Przykład 2.1: [Nazwa przykładu]

# %%
# Przykład 2.1

# Twój kod tutaj

# %% [markdown]
# ## Porównanie PySpark vs SQL (jeśli dotyczy)
#
# **DataFrame API (PySpark):**

# %%
# Podejście PySpark

# Twój kod tutaj

# %% [markdown]
# **SQL Equivalent:**

# %%
# Podejście SQL

# Twój kod tutaj (może być %sql magic command)

# %% [markdown]
# **Porównanie:**
# - **Wydajność**: [Identyczna - Catalyst optimizer]
# - **Kiedy używać PySpark**: [Przypadki użycia]
# - **Kiedy używać SQL**: [Przypadki użycia]

# %% [markdown]
# ## Zadania praktyczne (tylko dla warsztatów)
#
# ### Zadanie 1: [Nazwa zadania]
#
# **Instrukcje:**
# 1. [Szczegółowy krok 1]
# 2. [Szczegółowy krok 2]
# 3. [Szczegółowy krok 3]
#
# **Oczekiwany rezultat:**
# - [Opisz co powinno się stać]
# - [Jakie dane powinny być widoczne]
#
# **Wskazówki:**
# - Użyj funkcji: `[lista funkcji]`
# - Pamiętaj o: `[ważne aspekty]`

# %%
# TODO: Uzupełnij kod zgodnie z instrukcjami powyżej

# Szkielet kodu dla ułatwienia:
# df = spark.read...
#
# # Twój kod tutaj
#
# display(df)

# %% [markdown]
# ### Zadanie 2: [Nazwa zadania]
#
# **Instrukcje:**
# [Szczegółowe instrukcje]

# %%
# TODO: [Opis zadania do wykonania]

# Twój kod tutaj

# %% [markdown]
# ## Walidacja i weryfikacja
#
# ### Checklist - Co powinieneś uzyskać:
# - [ ] [Rezultat 1 - np. Tabela utworzona w schemacie]
# - [ ] [Rezultat 2 - np. Dane przetworzone poprawnie]
# - [ ] [Rezultat 3 - np. Brak błędów w logach]
# - [ ] [Rezultat 4 - np. Wydajność optymalna]
#
# ### Komendy weryfikacyjne:

# %%
# Weryfikacja wyników

print("=== WERYFIKACJA WYNIKÓW ===")

# 1. Sprawdź liczbę rekordów
# count = spark.table(f"{CATALOG}.{SCHEMA}.table_name").count()
# print(f"Liczba rekordów: {count}")

# 2. Sprawdź schemat
# spark.table(f"{CATALOG}.{SCHEMA}.table_name").printSchema()

# 3. Podgląd danych
# display(spark.table(f"{CATALOG}.{SCHEMA}.table_name").limit(10))

# 4. Historia operacji (dla Delta)
# display(spark.sql(f"DESCRIBE HISTORY {CATALOG}.{SCHEMA}.table_name"))

# Testy asercyjne (dla warsztatów)
# assert count > 0, "Błąd: Tabela jest pusta"
# assert len(columns) == expected_columns, "Błąd: Niepoprawna liczba kolumn"

print("Wszystkie testy przeszły pomyślnie!")

# %% [markdown]
# ## Troubleshooting
#
# ### Problem 1: [Typowy problem]
# **Objawy:**
# - [Jak rozpoznać problem]
# - [Komunikaty błędów]
#
# **Rozwiązanie:**
# ```python
# # Kod naprawczy lub komendy
# ```
#
# ### Problem 2: [Typowy problem]
# **Objawy:** [Opis]
#
# **Rozwiązanie:** [Kroki naprawcze]
#
# ### Problem 3: [Typowy problem]
# **Rozwiązanie:** [Kroki naprawcze]
#
# ### Debugging tips:
# - Użyj `.explain()` aby zobaczyć plan wykonania
# - Sprawdź logi klastra w Spark UI
# - Weryfikuj typy danych: `df.printSchema()`
# - Monitoruj metryki: liczba partycji, shuffle, spill

# %% [markdown]
# ## Best Practices
#
# ### Wydajność:
# - [Best practice 1 dotycząca wydajności]
# - [Best practice 2]
# - [Best practice 3]
#
# ### Jakość kodu:
# - [Best practice dotycząca kodu]
# - [Best practice 2]
#
# ### Data Quality:
# - [Best practice dotycząca jakości danych]
# - [Best practice 2]
#
# ### Governance:
# - [Best practice dotycząca bezpieczeństwa]
# - [Best practice 2]

# %% [markdown]
# ## Podsumowanie
#
# ### Co zostało osiągnięte:
# - [Osiągnięcie 1]
# - [Osiągnięcie 2]
# - [Osiągnięcie 3]
# - [Osiągnięcie 4]
#
# ### Kluczowe wnioski:
# 1. **[Wniosek 1]**: [Wyjaśnienie]
# 2. **[Wniosek 2]**: [Wyjaśnienie]
# 3. **[Wniosek 3]**: [Wyjaśnienie]
#
# ### Quick Reference - Najważniejsze komendy:
#
# | Operacja | PySpark | SQL |
# |----------|---------|-----|
# | [Operacja 1] | `kod` | `SELECT ...` |
# | [Operacja 2] | `kod` | `kod` |
# | [Operacja 3] | `kod` | `kod` |
#
# ### Następne kroki:
# - **Kolejny notebook**: [Nazwa następnego notebooka]
# - **Warsztat praktyczny**: [Nazwa warsztatu jeśli demo]
# - **Materiały dodatkowe**: [Linki do dodatkowych zasobów]
# - **Zadanie domowe** (opcjonalnie): [Opis zadania do samodzielnego wykonania]

# %% [markdown]
# ## Czyszczenie zasobów
#
# Posprzątaj zasoby utworzone podczas notebooka:

# %%
# Opcjonalne czyszczenie zasobów testowych
# UWAGA: Uruchom tylko jeśli chcesz usunąć wszystkie utworzone dane

# Usuń tabele tymczasowe
# spark.sql(f"DROP TABLE IF EXISTS {CATALOG}.{BRONZE_SCHEMA}.temp_table")

# Usuń widoki
# spark.sql("DROP VIEW IF EXISTS temp_view")

# Wyczyść cache
# spark.catalog.clearCache()

print("Zasoby zostały wyczyszczone")
